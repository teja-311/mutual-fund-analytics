# %% [markdown]
# # Fund Performance Analytics
#
# 1) This notebook evaluates mutual fund performance using return, risk, alpha, beta, Sharpe ratio, Sortino ratio, and maximum drawdown metrics.
#
# 2) The objective is to identify top-performing funds and compare them against benchmark indices.

# %%
import pandas as pd
perf = pd.read_csv("../data/processed/clean_scheme_performance.csv")
perf.head()
# Out:
#    amfi_code                                   scheme_name       fund_house  \
# 0     119551     SBI Bluechip Fund - Regular Plan - Growth  SBI Mutual Fund
# 1     119552      SBI Bluechip Fund - Direct Plan - Growth  SBI Mutual Fund
# 2     119598    SBI Small Cap Fund - Regular Plan - Growth  SBI Mutual Fund
# 3     119599     SBI Small Cap Fund - Direct Plan - Growth  SBI Mutual Fund
# 4     119120  SBI Magnum Gilt Fund - Regular Plan - Growth  SBI Mutual Fund
#
#     category     plan  return_1yr_pct  return_3yr_pct  return_5yr_pct  \
# 0  Large Cap  Regular           12.42           12.36           14.45
# 1  Large Cap   Direct           15.25           11.30           14.23
# 2  Small Cap  Regular           24.56           23.39           20.67
# 3  Small Cap   Direct           20.59           23.14           21.82
# 4       Gilt  Regular            5.34            6.07            5.43
#
#    benchmark_3yr_pct  alpha  beta  sharpe_ratio  sortino_ratio  \
# ...

# %% [markdown]
# ## Top 10 Funds by Composite Score
#
# Funds were ranked using a weighted scorecard based on:
#
# i) 30% Return Rank
# ii) 25% Sharpe Rank
# iii) 20% Alpha Rank
# iv) 15% Expense Ratio Rank
# v) 10% Drawdown Rank

# %%
scorecard = pd.read_csv("../reports/fund_scorecard.csv")
scorecard.head(10)
# Out:
#                                      scheme_name                fund_house  \
# 0      SBI Small Cap Fund - Direct Plan - Growth           SBI Mutual Fund
# 1         Kotak Flexicap Fund - Regular - Growth         Kotak Mahindra MF
# 2  Kotak Emerging Equity Fund - Regular - Growth         Kotak Mahindra MF
# 3         ABSL Small Cap Fund - Regular - Growth  Aditya Birla Sun Life MF
# 4     SBI Small Cap Fund - Regular Plan - Growth           SBI Mutual Fund
# 5  Mirae Asset Large Cap Fund - Regular - Growth            Mirae Asset MF
# 6   HDFC Short Term Debt Fund - Regular - Growth          HDFC Mutual Fund
# 7       ICICI Pru Liquid Fund - Regular - Growth       ICICI Prudential MF
# 8       ICICI Pru Midcap Fund - Regular - Growth       ICICI Prudential MF
# 9      ICICI Pru Bluechip Fund - Direct - Growth       ICICI Prudential MF
#
#    return_3yr_pct  sharpe_ratio  alpha  expense_ratio_pct  max_drawdown_pct  \
# ...

# %% [markdown]
# SBI Small Cap Fund achieved the highest composite score due to its strong return performance and competitive risk-adjusted metrics.

# %% [markdown]
# ## Benchmark Comparison
#
# 1) The top-performing mutual funds were compared against their benchmark returns.
#
# 2) This helps determine whether the fund manager generated excess returns beyond the benchmark.

# %%
import pandas as pd
top5 = pd.read_csv("../data/processed/clean_scheme_performance.csv")

top5 = top5.sort_values(
    "return_3yr_pct",
    ascending=False
).head(5)

top5[
    [
        "scheme_name",
        "return_3yr_pct",
        "benchmark_3yr_pct"
    ]
]
# Out:
#                                        scheme_name  return_3yr_pct  \
# 2       SBI Small Cap Fund - Regular Plan - Growth           23.39
# 3        SBI Small Cap Fund - Direct Plan - Growth           23.14
# 29          ABSL Small Cap Fund - Regular - Growth           22.38
# 27          Axis Small Cap Fund - Regular - Growth           20.98
# 17  Nippon India Small Cap Fund - Regular - Growth           20.15
#
#     benchmark_3yr_pct
# 2               22.16
# 3               22.01
# 29              20.54
# 27              20.47
# 17              19.35
